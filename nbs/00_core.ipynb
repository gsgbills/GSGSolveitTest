# %% [markdown]
# # core
#
# > Fill in a module description here

# %%
#| default_exp core

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(a: int): 
    "This passes"
    pass

# %% [markdown]
# "This does nothing"

# %%
foo(1)

# %%
#| hide
import nbdev; nbdev.nbdev_export()
