# %% [markdown]
# # core
#
# > Fill in a module description here

# %%
#| default_exp core2

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(
    a:int # defines as int argument
): 
    "This just passes"
    pass

# %% [markdown]
# "This does nothing"

# %%
foo(1)

# %%
#| hide
import nbdev; nbdev.nbdev_export()
